# %% [markdown]
# ## Introduction to Streamlit
# Streamlit is an open-source app framework for Machine Learning and Data Science projects.It allows you to create beautiful web applications for our machine learning and data science projects with simple Python scripts.
